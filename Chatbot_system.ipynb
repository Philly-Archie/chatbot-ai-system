# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
botpress = pd.read_csv("BP_MHS_V1.csv")
botpress
# Out:
#                                     qid  \
# 0      b02bf6ef2b24c6e8d70323f309f50b76
# 1      b02bf6ef2b24c6e8d70323f309f50b76
# 2      b02bf6ef2b24c6e8d70323f309f50b76
# 3      b02bf6ef2b24c6e8d70323f309f50b76
# 4      52da577318c75bebd72273772678ec8d
# ...                                 ...
# 40147  da4a0587c9ae2562903f3558c2bd00da
# 40148  5f448646ecd4bb0f897992b8a5f13141
# 40149  5f448646ecd4bb0f897992b8a5f13141
# 40150  5f448646ecd4bb0f897992b8a5f13141
# 40151  5f448646ecd4bb0f897992b8a5f13141
#
#                                                 question  \
# 0      My parents are celebrating their anniversary a...
# 1      My parents are celebrating their anniversary a...
# 2      My parents are celebrating their anniversary a...
# 3      My parents are celebrating their anniversary a...
# 4      The tall and charming design makes me think th...
# ...                                                  ...
# 40147  Can you give me proof that the room is comfort...
# ...

# %%
botpress.columns
# Out:
# Index(['qid', 'question', 'related_facts', 'answer_in_fact', 'engine',
#        'engine_response', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9',
#        'p10', 'best', 'worst', 'annotation_round'],
#       dtype='object')

# %%
botpress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40152 entries, 0 to 40151
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   qid               40152 non-null  object
#  1   question          40152 non-null  object
#  2   related_facts     39544 non-null  object
#  3   answer_in_fact    40152 non-null  bool
#  4   engine            40152 non-null  object
#  5   engine_response   40152 non-null  object
#  6   p1                40152 non-null  bool
#  7   p2                40152 non-null  bool
#  8   p3                40152 non-null  bool
#  9   p4                40152 non-null  bool
#  10  p5                40152 non-null  bool
#  11  p6                40152 non-null  bool
#  12  p7                40152 non-null  bool
#  13  p8                40152 non-null  bool
#  14  p9                40152 non-null  bool
#  15  p10               40152 non-null  bool
# ...

# %%
botpress.describe()
# Out:
#        annotation_round
# count           40152.0
# mean                1.0
# std                 0.0
# min                 1.0
# 25%                 1.0
# 50%                 1.0
# 75%                 1.0
# max                 1.0

# %%
botpress.head()
# Out:
#                                 qid  \
# 0  b02bf6ef2b24c6e8d70323f309f50b76
# 1  b02bf6ef2b24c6e8d70323f309f50b76
# 2  b02bf6ef2b24c6e8d70323f309f50b76
# 3  b02bf6ef2b24c6e8d70323f309f50b76
# 4  52da577318c75bebd72273772678ec8d
#
#                                             question  \
# 0  My parents are celebrating their anniversary a...
# 1  My parents are celebrating their anniversary a...
# 2  My parents are celebrating their anniversary a...
# 3  My parents are celebrating their anniversary a...
# 4  The tall and charming design makes me think th...
#
#                                        related_facts  answer_in_fact  \
# 0  Montréal Hotel & Suites was built in 2009. The...            True
# 1  Montréal Hotel & Suites was built in 2009. The...            True
# 2  Montréal Hotel & Suites was built in 2009. The...            True
# 3  Montréal Hotel & Suites was built in 2009. The...            True
# 4  Montréal Hotel & Suites was built in 2009. The...            True
#
# ...

# %%
botpress.columns
# Out:
# Index(['qid', 'question', 'related_facts', 'answer_in_fact', 'engine',
#        'engine_response', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9',
#        'p10', 'best', 'worst', 'annotation_round'],
#       dtype='object')

# %%
botpress.duplicated().sum()
# Out:
# 20076

# %%
botpress.head()
# Out:
#                                 qid  \
# 0  b02bf6ef2b24c6e8d70323f309f50b76
# 1  b02bf6ef2b24c6e8d70323f309f50b76
# 2  b02bf6ef2b24c6e8d70323f309f50b76
# 3  b02bf6ef2b24c6e8d70323f309f50b76
# 4  52da577318c75bebd72273772678ec8d
#
#                                             question  \
# 0  My parents are celebrating their anniversary a...
# 1  My parents are celebrating their anniversary a...
# 2  My parents are celebrating their anniversary a...
# 3  My parents are celebrating their anniversary a...
# 4  The tall and charming design makes me think th...
#
#                                        related_facts  answer_in_fact  \
# 0  Montréal Hotel & Suites was built in 2009. The...               1
# 1  Montréal Hotel & Suites was built in 2009. The...               1
# 2  Montréal Hotel & Suites was built in 2009. The...               1
# 3  Montréal Hotel & Suites was built in 2009. The...               1
# 4  Montréal Hotel & Suites was built in 2009. The...               1
#
# ...

# %%
botpress.duplicated().sum()
# Out:
# 20076

# %%
from sklearn.preprocessing import LabelEncoder

# %%
botpress.best = LabelEncoder().fit_transform(botpress.best)
botpress.worst = LabelEncoder().fit_transform(botpress.worst)
botpress.answer_in_fact = LabelEncoder().fit_transform(botpress.answer_in_fact)
botpress.head()
# Out:
#                                 qid  \
# 0  b02bf6ef2b24c6e8d70323f309f50b76
# 1  b02bf6ef2b24c6e8d70323f309f50b76
# 2  b02bf6ef2b24c6e8d70323f309f50b76
# 3  b02bf6ef2b24c6e8d70323f309f50b76
# 4  52da577318c75bebd72273772678ec8d
#
#                                             question  \
# 0  My parents are celebrating their anniversary a...
# 1  My parents are celebrating their anniversary a...
# 2  My parents are celebrating their anniversary a...
# 3  My parents are celebrating their anniversary a...
# 4  The tall and charming design makes me think th...
#
#                                        related_facts  answer_in_fact  \
# 0  Montréal Hotel & Suites was built in 2009. The...               1
# 1  Montréal Hotel & Suites was built in 2009. The...               1
# 2  Montréal Hotel & Suites was built in 2009. The...               1
# 3  Montréal Hotel & Suites was built in 2009. The...               1
# 4  Montréal Hotel & Suites was built in 2009. The...               1
#
# ...

# %%
botpress.plot(kind = 'scatter', x = 'engine', y = 'best')
botpress.plot(kind = 'scatter', x = 'engine', y = 'worst')
# Out:
# <AxesSubplot:xlabel='engine', ylabel='worst'>

# %%
botpress['worst'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
botpress.pivot(columns = 'engine', values = 'worst')
# Out:
# engine  dialogflow  openbook  rasa  watson
# 0              1.0       NaN   NaN     NaN
# 1              NaN       0.0   NaN     NaN
# 2              NaN       NaN   0.0     NaN
# 3              NaN       NaN   NaN     0.0
# 4              NaN       0.0   NaN     NaN
# ...            ...       ...   ...     ...
# 40147          0.0       NaN   NaN     NaN
# 40148          NaN       NaN   NaN     0.0
# 40149          NaN       0.0   NaN     NaN
# 40150          NaN       NaN   0.0     NaN
# 40151          0.0       NaN   NaN     NaN
#
# [40152 rows x 4 columns]

# %%
botpress.pivot(columns = 'engine', values = 'worst').plot(kind = 'box', figsize = (10.6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6796\3568734703.py in <module>
# ----> 1 botpress.pivot(columns = 'engine', values = 'worst').plot(kind = 'box', figsize = (10.6))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
botpress.groupby('engine')['best'].values.counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10048\1626368951.py in <module>
# ----> 1 botpress.groupby('engine')['best'].values.counts()
#
# NameError: name 'botpress' is not defined

# %%
botpress = pd.read_csv("BP_MHS_V1.csv")
botpress
response = 'annotation_round'
y = botpress[[response]]
y
# Out:
#        annotation_round
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 40147                 1
# 40148                 1
# 40149                 1
# 40150                 1
# 40151                 1
#
# [40152 rows x 1 columns]

# %%
y.head()
# Out:
#     best
# 0  False
# 1   True
# 2  False
# 3  False
# 4   True

# %%
my_columns = list(botpress.columns)
my_columns
# Out:
# ['qid',
#  'question',
#  'related_facts',
#  'answer_in_fact',
#  'engine',
#  'engine_response',
#  'p1',
#  'p2',
#  'p3',
#  'p4',
#  'p5',
#  'p6',
#  'p7',
#  'p8',
#  'p9',
#  'p10',
#  'best',
#  'worst',
#  'annotation_round']

# %%
my_columns.remove(response)
my_columns
# Out:
# ['qid',
#  'question',
#  'related_facts',
#  'answer_in_fact',
#  'engine',
#  'engine_response',
#  'p1',
#  'p2',
#  'p3',
#  'p4',
#  'p5',
#  'p6',
#  'p7',
#  'p8',
#  'p9',
#  'p10',
#  'worst']

# %%
x = botpress[my_columns]
x.head()
# Out:
#                                 qid  \
# 0  b02bf6ef2b24c6e8d70323f309f50b76
# 1  b02bf6ef2b24c6e8d70323f309f50b76
# 2  b02bf6ef2b24c6e8d70323f309f50b76
# 3  b02bf6ef2b24c6e8d70323f309f50b76
# 4  52da577318c75bebd72273772678ec8d
#
#                                             question  \
# 0  My parents are celebrating their anniversary a...
# 1  My parents are celebrating their anniversary a...
# 2  My parents are celebrating their anniversary a...
# 3  My parents are celebrating their anniversary a...
# 4  The tall and charming design makes me think th...
#
#                                        related_facts  answer_in_fact  \
# 0  Montréal Hotel & Suites was built in 2009. The...            True
# 1  Montréal Hotel & Suites was built in 2009. The...            True
# 2  Montréal Hotel & Suites was built in 2009. The...            True
# 3  Montréal Hotel & Suites was built in 2009. The...            True
# 4  Montréal Hotel & Suites was built in 2009. The...            True
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train.shape
# Out:
# (30114, 17)

# %%
y_train.shape
# Out:
# (30114, 1)

# %%
x_test.shape
# Out:
# (10038, 17)

# %%
y_test.shape
# Out:
# (10038, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 1234)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train, y_train)

# %%
model.intercept_

# %%
model.coef_

# %%
model.score(x_test, y_test)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_abslute_error(y_test, y_pred)
